# %% [markdown]
# CHAT BOT
#
# A chat bot is an AI that comminicates
#
# Technically a chat bot is a program that does three things:
#
#    1.Accept user message /prompt given by the user
#
#    2.Chatbot should remember the prior message in the same conversation
#
#    3.Based on the information inside conversation it should generate relevant replies
#
#    ___________________________________________________________________

# %% [markdown]
# response=client.models.generate_content()
#
#  -Every time we call it, gemini will treat as a new request, it doesn't automatically remembers what we asked before
#
# chats.create()
#
# -Conversation with previous message/context
#
# ____________________________________________________________________
#
# SOLUTIONS
#
# 1.Brute force approach

# %%
# !pip install -q -U google-genai

from google import genai
from google.genai import types
from google.colab import userdata
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 20.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.

# %%
client=genai.Client(api_key=userdata.get('Ragproject'))

# %%
conversation="""
User: Hi im Nachammai
Bot: Hi Nachammai, How can i help you
User: what is my name?
Bot: Nachammai
User:im 21 years old
Bot:Got it, Nachammai! You're 21 years old.
"""

user=input("User:")
conversation=conversation + f"\nUser:{user}"

response=client.models.generate_content(
    model='gemini-3.5-flash-lite',
    contents=conversation,
)

conversation+=f"\nBot:{response.text}"

print(f"Bot:{response.text}")


print("\nConversation History:")
print(conversation)
# Out:
# User:hii im Nachammai
# Bot:Hi Nachammai! It looks like you're saying hello again. How can I help you today?
#
# Conversation History:
#
# User: Hi im Nachammai
# Bot: Hi Nachammai, How can i help you
# User: what is my name?
# Bot: Nachammai
# User:im 21 years old
# Bot:Got it, Nachammai! You're 21 years old.
#
# User:hii im Nachammai
# Bot:Hi Nachammai! It looks like you're saying hello again. How can I help you today?

# %% [markdown]
# 2.SDK provides Client.chats.create()

# %%
from google import genai
from google.genai import types
from google.colab import userdata

client=genai.Client(api_key=userdata.get('Ragproject'))

chat=client.chats.create(
    model='gemini-3.5-flash-lite',
    config=types.GenerateContentConfig(
        system_instruction="you are a helpful assistant who answer the user question in simple and formal way"
    ),
    history=[]
)

print("Bot is ready to help you!")
print("Enter exit or bye to leave the chat")

while True:
  user_input=input("You:")
  if user_input.lower() in['exit','bye']:
    print("Bot: Goodbye! Have a great day!")
    break

  reply=chat.send_message(user_input)
  print(f"Bot:{reply.text}")
# Out:
# Bot is ready to help you!
# Enter exit or bye to leave the chat
# You:hii im 21 years old
# Bot:Hello. It is a pleasure to meet you. How may I assist you today?
# You:what is my age ?
# Bot:Based on the information you provided earlier, you are 21 years old.
# You:bye
# Bot: Goodbye! Have a great day!
